# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Configuração dos Tickers (Blue Chips B3)
tickers_blue_chips = [
    'PETR4.SA',  # Petrobras
    'VALE3.SA',  # Vale
    'ITUB4.SA',  # Itaú
    'BBDC4.SA',  # Bradesco
    'WEGE3.SA',  # WEG
    'ABEV3.SA',  # Ambev
    'B3SA3.SA',  # B3
    'BBAS3.SA'   # Banco do Brasil
]

# %%
# 2. Download dos dados (Definindo período de 2 anos para ter histórico relevante)
print(f"Baixando dados para: {tickers_blue_chips}...")
dados_brutos = yf.download(tickers_blue_chips, period="2y", progress=False)
# Out:
# Failed to get ticker 'B3SA3.SA' reason: Failed to perform, curl: (77) error setting certificate verify locations:  CAfile: c:\Users\william.mendes\OneDrive\Área de Trabalho\projects\pos\tech_challenge_2_mlet\.venv\Lib\site-packages\certifi\cacert.pem CApath: none. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# Failed to get ticker 'BBDC4.SA' reason: Failed to perform, curl: (77) error setting certificate verify locations:  CAfile: c:\Users\william.mendes\OneDrive\Área de Trabalho\projects\pos\tech_challenge_2_mlet\.venv\Lib\site-packages\certifi\cacert.pem CApath: none. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# ...
